# %% [markdown]
# # axis and reductions

# %%
import numpy as np
a = np.array([[1, 2, 3],
                [4, 5, 6]])

# %%
a.shape
# Out:
# (2, 3)

# %%
a.strides # 24 bytest to got next row # 8 byetes to next element in colun rows = 24, columns = 8)
# Out:
# (24, 8)

# %%
np.sum(a)
# Out:
# np.int64(21)

# %%
np.mean(a)
# Out:
# np.float64(3.5)

# %%
a.mean()
# Out:
# np.float64(3.5)

# %%
a.min()
# Out:
# np.int64(1)

# %%
a.max()
# Out:
# np.int64(6)

# %%
a.std()
# Out:
# np.float64(1.707825127659933)

# %%
np.sum(a, axis=0) # this will reduce number or rows # 0th position is rows and 1st axis is to reduce columns
# Out:
# array([5, 7, 9])

# %%
np.sum(a, axis=1) # this will reduce number of columns, addition happens column wise
# Out:
# array([ 6, 15])

# %%
a.sum(axis=1)
# Out:
# array([ 6, 15])

# %%
a.sum(axis=0)
# Out:
# array([5, 7, 9])

# %%
b = a.reshape(3, 2)
print(b)
a.shape = (6, 1)
print(a)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]
#  [6]]
