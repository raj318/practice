# %%
import numpy as np

# %%
a = np.array([1, 2, 3, 4, 5])
a+10 # adds 10 to each element of the array, 10 is broadcasted to all elements in the array
# Out:
# array([11, 12, 13, 14, 15])

# %%
b = np.array([
    [10],
    [20],
    [30]
])
b
# Out:
# array([[10],
#        [20],
#        [30]])

# %%
c = np.array([[10, 20, 30, 40, 50]])

# %%
print(a.shape)
print(b.shape)
print(c.shape)
# Out:
# (5,)
# (3, 1)
# (1, 5)

# %%
b+a # a = (5,) converts to (1, 5)
# b = (3, 1))
# Out:
# array([[11, 12, 13, 14, 15],
#        [21, 22, 23, 24, 25],
#        [31, 32, 33, 34, 35]])

# %%
a+b
# Out:
# array([[11, 12, 13, 14, 15],
#        [21, 22, 23, 24, 25],
#        [31, 32, 33, 34, 35]])

# %%
d = np.array([
    [1, 2, 3],
    [4, 5, 6]
])

e = np.array([
    [10, 20],
    [30, 40],
    [50, 60]
])

aa = np.array([1, 2, 3])

# %%
print(a.shape)
print(aa.shape)
print(b.shape)
print(c.shape)
print(d.shape)
print(e.shape)
# Out:
# (5,)
# (3,)
# (3, 1)
# (1, 5)
# (2, 3)
# (3, 2)

# %%
b + e
# Out:
# array([[20, 30],
#        [50, 60],
#        [80, 90]])

# %%
b + e
# Out:
# array([[20, 30],
#        [50, 60],
#        [80, 90]])

# %%
d + aa
# Out:
# array([[2, 4, 6],
#        [5, 7, 9]])

# %%
np.ones((2, 3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])
