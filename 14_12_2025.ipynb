# %% [markdown]
# 1. X (m*n) :
#
# m -> no of observations
# n -> no of features (dimentaions)
#
# Y (m*n) : target of m observations
#
# Supervised learning: classified into two
#
# 1. classification (
#         y is descrete,
#         process of creating decision boundaries,
#         process of identifying class by dividing the featues plane)
# 2. regression (
#         y is continuous,
#         process of identifying correlation between features and target)

# %% [markdown]
# y = mx + c
#
# Lets call m as a theta
