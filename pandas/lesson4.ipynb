# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Stock': ['TCS', 'INFY', 'BEL', 'NVDA'],
    'Price': [300, 1500, 200, 500],
    'quantity': [5, 10, 15, 56]
})

# %%
df[['Price']] >200
# Out:
#    Price
# 0   True
# 1   True
# 2  False
# 3   True

# %%
df[df[['Price']]> 200]
# Out:
#   Stock   Price  quantity
# 0   NaN   300.0       NaN
# 1   NaN  1500.0       NaN
# 2   NaN     NaN       NaN
# 3   NaN   500.0       NaN

# %%
df[(df['Price']>200) & (df['quantity']> 10)]
# Out:
#   Stock  Price  quantity
# 3  NVDA    500        56

# %%
df[(df['Price']> 300) | (df['quantity']> 40)]
# Out:
#   Stock  Price  quantity
# 1  INFY   1500        10
# 3  NVDA    500        56

# %%
df.loc[(df['Price'] > 200), ['Stock']]
# Out:
#   Stock
# 0   TCS
# 1  INFY
# 3  NVDA

# %%
df[df['Stock'].isin(['RELIANCE', 'TCS'])]
df['Stock'].isin(['RELIANCE', 'TCS'])
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# Name: Stock, dtype: bool

# %%
df[df["Price"] > 300][["Price", "Price"]]
# Out:
#    Price  Price
# 1   1500   1500
# 3    500    500
