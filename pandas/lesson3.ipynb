# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'stock': ['INFY', "TCL", 'BEL'],
    'price': [500, 150, 750],
    'quantity': [10, 20, 15]
})

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.iloc[2]
# Out:
# stock       BEL
# price       750
# quantity     15
# Name: 2, dtype: object

# %%
df.iloc[0:3]
# Out:
#   stock  price  quantity
# 0  INFY    500        10
# 1   TCL    150        20
# 2   BEL    750        15

# %%
df.iloc[1,2]
# Out:
# np.int64(20)

# %%
int(df.iloc[1, 2])
# Out:
# 20

# %%
df.loc[0]
# Out:
# stock       INFY
# price        500
# quantity      10
# Name: 0, dtype: object

# %%
df.loc[0:1]
# Out:
#   stock  price  quantity
# 0  INFY    500        10
# 1   TCL    150        20

# %%
df2 = df.set_index('stock')

# %%
df2
# Out:
#        price  quantity
# stock
# INFY     500        10
# TCL      150        20
# BEL      750        15

# %%
df2.loc['INFY']
# Out:
# price       500
# quantity     10
# Name: INFY, dtype: int64

# %%
df.iloc[0, 1]
# Out:
# np.int64(500)

# %%
df.loc[0, 'price']
# Out:
# np.int64(500)
