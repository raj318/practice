# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Stock': ['TCL', 'TCV', "POWERGRID"],
    'Price': [740, 455, 430],
    'Quantity': [117, 23, 45]
})

# %%
df['Price']
# Out:
# 0    740
# 1    455
# 2    430
# Name: Price, dtype: int64

# %%
df.Price
# Out:
# 0    740
# 1    455
# 2    430
# Name: Price, dtype: int64

# %%
df['Stock']
# Out:
# 0          TCL
# 1          TCV
# 2    POWERGRID
# Name: Stock, dtype: object

# %%
type(df["Stock"]) # though : data frame but got data series
# Out:
# pandas.core.series.Series

# %%
type(df[['Stock']]) # data frame
# Out:
# pandas.core.frame.DataFrame

# %%
df[['Price', 'Stock', 'Price']]
# Out:
#    Price      Stock  Price
# 0    740        TCL    740
# 1    455        TCV    455
# 2    430  POWERGRID    430

# %%
'Pri' in df.columns
# Out:
# False

# %%
df = pd.DataFrame({
    'Stock': ['TCL', 'INFY', "COALINDIA"],
    'Price': [740, 455, 430],
    'Quantity': [117, 23, 45]
}, index=['TCL', 'INFY', "COALINDIA"])

# %%
df
# Out:
#                Stock  Price  Quantity
# TCL              TCL    740       117
# INFY            INFY    455        23
# COALINDIA  COALINDIA    430        45

# %%
df[:"INFY"]
# Out:
#      Stock  Price  Quantity
# TCL    TCL    740       117
# INFY  INFY    455        23

# %%
df.loc[:2]
# Out:
#   Stock  Price  Quantity
# 0   TCL    740       117
# 1   TCL    455        23
# 2   TCL    430        45

# %%
df.loc[df['Stock'] == 'TCL', :]
# Out:
#   Stock  Price  Quantity
# 0   TCL    740       117
# 1   TCL    455        23
