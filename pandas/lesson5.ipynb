# %%
import pandas as pd

df = pd.DataFrame({
    'stocks': ['INFY', 'TCS', 'COALINDIA'],
    'price': [100, 150, 300],
    'qty': [10, 10, 30]
})

# %% [markdown]
# This is called vectorization (powered by NumPy underneath).

# %%
df['value'] = df['price'] * df['qty']

# %%
df
# Out:
#       stocks  price  qty  value
# 0       INFY    100   10   1000
# 1        TCS    150   10   1500
# 2  COALINDIA    300   30   9000

# %%
df['test'] = 'normal'

# %%
df
# Out:
#       stocks  price  qty  value category    test
# 0       INFY    100   10   1000   normal  normal
# 1        TCS    150   10   1500   normal  normal
# 2  COALINDIA    300   30   9000   normal  normal

# %%
df.loc[df['price'] > 100, ['category']] = 'expensive'

# %%
df
# Out:
#       stocks  price  qty  value   category    test
# 0       INFY    100   10   1000     normal  normal
# 1        TCS    150   10   1500  expensive  normal
# 2  COALINDIA    300   30   9000  expensive  normal
