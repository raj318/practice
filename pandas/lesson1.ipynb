# %%
import pandas as pd

# %%
series = pd.Series([1, 3, 5, 7, 10], index=['a', 'b', 'c', 'd', 'e'])
print(series)
# Out:
# a     1
# b     3
# c     5
# d     7
# e    10
# dtype: int64

# %%
series.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df = pd.DataFrame({
    'name': ['Amit', 'Bharat', 'Sai'],
    'age': [25, 28, 27],
    'city': ['Delhi', 'tirupati', 'Mumbai']
}, index=['Amit', 'Bharat', 'Sai'])
print(df)
# Out:
#           name  age      city
# Amit      Amit   25     Delhi
# Bharat  Bharat   28  tirupati
# Sai        Sai   27    Mumbai

# %%
df.index
# Out:
# Index(['Amit', 'Bharat', 'Sai'], dtype='object')

# %%
df.columns
# Out:
# Index(['name', 'age', 'city'], dtype='object')

# %%
df.size
# Out:
# 9

# %%
df.shape
# Out:
# (3, 3)

# %%
df.dtypes
# Out:
# name    object
# age      int64
# city    object
# dtype: object

# %%
# second example
df = pd.DataFrame({
    'stocks': ['TCS', 'INFY', 'WIPRO'],
    'price': [3500, 1500, 500],
    'quantity': [10, 15, 20]
}, index=['TCS', 'INFY', 'WIPRO'])
df
# Out:
#       stocks  price  quantity
# TCS      TCS   3500        10
# INFY    INFY   1500        15
# WIPRO  WIPRO    500        20

# %%
df.shape
# Out:
# (3, 3)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.dtypes
# Out:
# stocks      object
# price        int64
# quantity     int64
# dtype: object

# %%
df = pd.DataFrame({
    "a": [1, 2],
    "b": [3, 4],
    "c": [5, 6],
    "d": [7, 8]
})
df.shape
# Out:
# (2, 4)
