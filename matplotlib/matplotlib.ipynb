# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [10, 20, 25, 30]

plt.plot(x, y) 
# or 
plt.plot([1, 2, 3, 4, 5], [10, 20, 25, 30, 35], color = 'orange')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Simple Line Plot')
# plt.show() # still works only due to the fact that we are in a ipynb file environement
# Out:
# Text(0.5, 1.0, 'Simple Line Plot')

# %%
x = [1, 2, 3, 4]
y1 = [2, 4, 6, 8]
y2 = [1, 4, 9, 16]
y3 = [1, 7, 10, 16]

plt.plot(x, y1, label='Linear')
plt.plot(x, y2, label='Square')
plt.plot(x, y3, label='Y3')
plt.xlabel("X axis")
plt.ylabel("y1, y2, y3 axis")
plt.legend()
plt.title("Multiple line graphs")
plt.show()

# %%
plt.plot(x, y1, color='blue', label='Linear', linestyle='-', marker='o')
plt.plot(x, y2, color='red', label='Square', linestyle='--', marker='X')
plt.legend()
plt.show()

# %%
plt.plot([1, 2, 3], [1, 2, 3])
plt.show()

# %%
plt.plot([1, 2, 3,], [1, 2, 3])
plt.clf()
plt.plot([1, 2, 3,], [3, 2, 1])
plt.show()

# %%
x = [1, 2, 3, 4]
y = [10, 5, 20, 8]

plt.plot(x, y)
plt.title("Line Plot")
plt.show()

# %%
plt.scatter(x, y, color='red', marker='x', edgecolors='black')
plt.title('Scatter Plot')
plt.show()
# Out:
# /var/folders/cm/xbcw7tbj7ks0tkxmz2yy2pch0000gn/T/ipykernel_96142/3612405680.py:1: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   plt.scatter(x, y, color='red', marker='x', edgecolors='black')

# %%
sizes = [500, 100, 200, 80]
plt.scatter(x, y, s=sizes, color='red')
plt.show()

# %%
plt.scatter(x, y, alpha=0.4)
plt.show()

# %%
plt.scatter(x, y, label='Samples')
plt.legend()
plt.show()

# %%
plt.plot(x, y, 'o', alpha=0.6)

# %%
y = [10, 20, 2, 5, 11, 16, 50]
x = [1, 2, 3, 4, 5, 6, 7]
plt.figure()
plt.plot(x, y, label="plot line")
plt.legend()
plt.show()

plt.figure()
plt.scatter(x, y, label='scatter plot', color='red')
plt.legend()
plt.show()

# %%
categories = ['A', 'B', 'C', 'D']
values = [10, 20, 30, 40]

plt.bar(categories, values, label='bar chart')
plt.xlabel('categories')
plt.ylabel('values')
plt.title('Basic bar chart')
plt.legend()
plt.show()

# %% [markdown]
# ❌ Line plots
#
#
# ❌ Scatter plots
#
#
# ❌ Bar charts
#
# These all require 1-to-1 pairing.
#
# 👉 If a plot connects dots → lengths must match
#
#
# 👉 If a plot summarizes data → one list is enough

# %%
plt.barh(categories, values, label='horizontal bar chart', color='red')
plt.title("horizontal bar chart")
plt.legend()
plt.show()

# %%
import numpy as np
print(categories)
x = np.arange(len(categories))
print(x)
width = 0.4
temp1 = x - width/2
print(temp1)
temp2 = x + width/2
print(temp2)

twidth = 0.4

plt.bar(temp1, values, width=twidth, label='bar 1', color='green')
plt.bar(temp2, values, width=twidth, label='bar 2', color='red')

plt.xticks(x, categories) # x is used to plot graphs and x is generated based on categories
plt.legend()
plt.show()
# Out:
# ['A', 'B', 'C', 'D']
# [0 1 2 3]
# [-0.2  0.8  1.8  2.8]
# [0.2 1.2 2.2 3.2]

# %%
bars = plt.bar(categories, values, label='line plot')
for bar in bars:
    plt.text(
        # bar.get_x() + bar.get_width()/2,
        bar.get_x() + bar.get_width()/2,
        bar.get_height(),
        str(bar.get_height()),
        ha='center', # what is this space in which left and right is setting?
        va='bottom'
    )
plt.show()

# %%
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.scatter(x, y)

for xi, yi in zip(x, y):
    plt.text(xi+0.1, yi+0.1, str(yi), ha='center', va='bottom')

plt.show()
