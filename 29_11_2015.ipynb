# %% [markdown]
# EDA - exploratory data analysis
# GEO - plotting
# dynamic - plotting

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
import kagglehub
path = kagglehub.dataset_download("mlg-ulb/creditcardfraud")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 66.0M/66.0M [00:07<00:00, 9.21MB/s]
# Extracting files...
# Path to dataset files: /Users/raj/.cache/kagglehub/datasets/mlg-ulb/creditcardfraud/versions/3

# %% [markdown]
# PCA = principle component analysis
# dimentionality reduction
# SVD = singular value decomposition - youtube channel Steve brunton (engineering math differential equiations)

# %% [markdown]
# Credit card fault detection - https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# plotlyb

# %%
creditcard_df = pd.read_csv('/Users/raj/.cache/kagglehub/datasets/mlg-ulb/creditcardfraud/versions/3/creditcard.csv')
creditcard_df.head(20)
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1    0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2    1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3    1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4    2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# 5    2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728
# 6    4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708
# 7    7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118
# 8    7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 9    9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761
# 10  10.0  1.449044 -1.176339  0.913860 -1.375667 -1.971383 -0.629152
# 11  10.0  0.384978  0.616109 -0.874300 -0.094019  2.924584  3.317027
# 12  10.0  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230
# ...

# %%
plt.figure(figsize=(10, 6))
# plt.hist(creditcard_df[['Time', 'V1', 'V2']], bins = 1)
plt.scatter(creditcard_df['V3'], creditcard_df['V1'], alpha=0.8)
plt.show()

# %%
path = kagglehub.dataset_download("ayeshaseherr/delivery-logistics-dataset")
print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 563k/563k [00:01<00:00, 408kB/s]
# Extracting files...
# Path to dataset files: /Users/raj/.cache/kagglehub/datasets/ayeshaseherr/delivery-logistics-dataset/versions/1

# %%
logistics_df = pd.read_csv('/Users/raj/.cache/kagglehub/datasets/ayeshaseherr/delivery-logistics-dataset/versions/1/Delivery_Logistics.csv')
logistics_df.head(2)
# Out:
#    delivery_id delivery_partner      package_type vehicle_type delivery_mode  \
# 0       250.99        delhivery  automobile parts         bike      same day
# 1       250.99       xpressbees         cosmetics       ev van       express
#
#     region weather_condition  distance_km  package_weight_kg  \
# 0     west             clear        297.0              46.96
# 1  central              cold         89.6              47.39
#
#              delivery_time_hours            expected_time_hours delayed  \
# 0  1970-01-01 00:00:00.000000008  1970-01-01 00:00:00.000000008      no
# 1  1970-01-01 00:00:00.000000002  1970-01-01 00:00:00.000000003      no
#
#   delivery_status  delivery_rating  delivery_cost
# 0       delivered                3      1632.7206
# 1       delivered                5       640.1700

# %%
logistics_df['vehicle_type'].value_counts()
# Out:
# vehicle_type
# ev bike    4218
# van        4187
# scooter    4174
# bike       4160
# truck      4145
# ev van     4116
# Name: count, dtype: int64

# %% [markdown]
# 1. delivery partner along with and delivery ratings and cost
# 2. weather condition with devliery time hours and expected time hours and delayed
# 3. package type and weight against delivery mode and vehicle type to get it delivered on time
# 4. delivery mode against region and distance in km
# 5. delay based on various other parameters (delivery partner, vehicle type, delivery mode, region, distance_km)
# 6. for a delivery partner, what are delivery time hours and expected time hours

# %%
vehicle_types = logistics_df['vehicle_type'].unique()
vehicle_types
vehicle_type_count = logistics_df['vehicle_type'].value_counts()

# %%
plt.figure(figsize=(10, 6))
sns.

# %%
package_type = logistics_df['package_type'].unique()
package_type
# Out:
# array(['automobile parts', 'cosmetics', 'groceries', 'electronics',
#        'clothing', 'documents', 'fragile items', 'pharmacy', 'furniture'],
#       dtype=object)
