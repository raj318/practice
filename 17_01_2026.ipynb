# %% [markdown]
# Logistic regression:
#
#
# can we ues linear regression to separete tumar size agains having cancer data?
#
#
# * We can't use regression algo for classification problem (regression models are data sensitive)
#
# * MSE (error is effected by distance)
#
# * probability of point on the classification line in classification model should be 0.5
#
# *

# %% [markdown]
# Maimum likelyhood estimation
#
# * for a good model, product of probability increases the error decreases, we are trying to conviences that an predictions matches to reality
# * In pure data science terms,  we can say Y and ycap have less impurity
#
# ab = a* b
# log(ab) = log(a) + log(b): why?
#
# 10^5 = 10^2 * 10^3 (5 = 2+3 with base 10 in log)

# %% [markdown]
# model -> y = theta0 + theta1 * x1 + theta2* x2 ...
# (theta, x) belongs to R
#
# where y can be anything to get it to between 0 to 1
#
# sigmoid function?
#
#
# -infi <= Z <= +infi
#
# 0 <= 1/ (1 + e pow -z) <= 1>

# %% [markdown]
# Where J theta is minimum we will get optimum
#
# j theta = -yi ln(1/(1 + e pow )) - (1-yi)ln(1- (1/1+e -))

# %% [markdown]
# why this error function is cross convex?
#
# entropy is nothing but negative of log

# %% [markdown]
# how do you find minimum value of a function f(x) = -3xsquare + 4x
#
# A scalar value function X,
#
# Jakovian matrix?
