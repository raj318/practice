# %% [markdown]
# 1. core vs threads
# 2. DDP - Distributed Data parallel (part of precision training)
# 3. youtube channel: CS336
# 4. Convolution vs matrix multiplication
# 5. Inverse of matrics
# 6. bayes interval in linear regressions model training
# 7. Home Work: Adjusted R2 Score - how it indicates a mechine learning model ()
# 8. Cross valdation score? (only appliced to scoring and not for modelling)

# %%
import os, certifi
os.environ['SSL_CERT_FILE'] = certifi.where()
os.environ['REQUESTS_CA_BUNDLE'] = certifi.where()
print(certifi.where())
# Out:
# /Users/raj/Documents/Corpnce AI/practice/.venv/lib/python3.12/site-packages/certifi/cacert.pem

# %%
import pandas as pd

data = pd.read_csv('https://raw.githubusercontent.com/justmarkham/scikit-learn-videos/refs/heads/master/data/Advertising.csv')
data.drop('Unnamed: 0', axis = 1, inplace = True)

# %% [markdown]
# R2 score should be calculated for both training data and testing data
#
# usually 100% of data is divided into 80% training data and 20% training data
